# %%
pip install kss
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 42.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 131 kB 55.2 MB/s
# ...
#   Created wheel for kss: filename=kss-3.5.6-py3-none-any.whl size=42448525 sha256=e05a64bdb34fa1d5d306afd868eb2928b50c70f37fa427d57038d2402cccb58d
#   Stored in directory: /root/.cache/pip/wheels/f7/1e/7d/a31add1236183845fb9b2dfadd50636429a5fbcabd5f341c86
# Successfully built kss
# ...

# %%
pip install soynlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 416 kB 25.4 MB/s
# ...

# %%
# !pip install git+https://github.com/haven-jeon/PyKoSpacing.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/haven-jeon/PyKoSpacing.git to /tmp/pip-req-build-a3u66j67
#   Running command git clone -q https://github.com/haven-jeon/PyKoSpacing.git /tmp/pip-req-build-a3u66j67
# ...
#      |████████████████████████████████| 671.4 MB 1.6 kB/s
# ...
#      |████████████████████████████████| 463 kB 40.0 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 57.2 MB/s
# ...
#   Created wheel for pykospacing: filename=pykospacing-0.5-py3-none-any.whl size=2268638 sha256=f1740e2000c18fd903420c60cce5df92ff43011ca52f33f72de0de526f37bb91
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6gbxde6p/wheels/9b/93/81/a2a7dc8c66ede5bf30634d20635f32b95eac7ca2ea8844058b
# Successfully built pykospacing
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
# ...

# %%
# !pip install git+https://github.com/ssut/py-hanspell.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/ssut/py-hanspell.git to /tmp/pip-req-build-5a8tdfbg
#   Running command git clone -q https://github.com/ssut/py-hanspell.git /tmp/pip-req-build-5a8tdfbg
# ...
#   Created wheel for py-hanspell: filename=py_hanspell-1.1-py3-none-any.whl size=4868 sha256=cdb004bb409a01abfb29b53d24c052a631204da674fbcf213f3d4e1aebed7396
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m2ouszo8/wheels/ab/f5/7b/d4124bb329c905301baed80e2ae45aa14e824f62ebc3ec2cc4
# Successfully built py-hanspell
# ...

# %%
import kss
import soynlp
from pykospacing import Spacing
from hanspell import spell_checker

import pandas as pd
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_dir = '/content/preprocessed_VBZ_v5.csv'
train_df = pd.read_csv(train_dir)
train_df = train_df.drop(columns=['Unnamed: 0'])
train_df.head(10)
# Out:
#          word type                         v1                       v2  \
# 0  afterhours  VBZ      영업시간후의, 폐점시간의(영업 등)      영업시간후의, 폐점시간의(영업 등)
# 1     amniote  VBZ                     양막류의                     양막류의
# 2    amoeboid  VBZ             아메바 모양의[비슷한]             아메바 모양의[비슷한]
# 3       anger  VBZ                   화나게 하다                   화나게 하다
# 4      apodal  VBZ    [동물] 발이 없는, 배지느러미가 없는    [동물] 발이 없는, 배지느러미가 없는
# 5        bats  VBZ       [영·속어]  정신 이상의, 미친               정신 이상의, 미친
# 6        caky  VBZ              케이크 같은, 뭉쳐진              케이크 같은, 뭉쳐진
# 7   catalyses  VBZ          [화학]  촉매 작용을 하다                촉매 작용을 하다
# 8   chemurgic  VBZ                  농예 화학의.                  농예 화학의.
# 9      chichi  VBZ     (장식이) 지나치게 복잡한[멋 부린]     (장식이) 지나치게 복잡한[멋 부린]
#
#                         v3  유의어                       v4                 v5  \
# 0    영업시간후의, 폐점시간의(영업 등)    NaN    영업시간후의, 폐점시간의(영업 등)        영업시간후의, 폐점시간의
# ...

# %%
def remove_useless_breacket(texts):
    """
    위키피디아 전처리를 위한 함수입니다.
    괄호 내부에 의미가 없는 정보를 제거합니다.
    아무런 정보를 포함하고 있지 않다면, 괄호를 통채로 제거합니다.
    ``수학(,)`` -> ``수학``
    ``수학(數學,) -> ``수학(數學)``
    """
    bracket_pattern = re.compile(r"\((.*?)\)")
    preprocessed_text = []
    for text in texts:
        modi_text = ""
        text = text.replace("()", "")  # 수학() -> 수학
        brackets = bracket_pattern.search(text)
        if not brackets:
            if text:
                preprocessed_text.append(text)
                continue
        replace_brackets = {}
        # key: 원본 문장에서 고쳐야하는 index, value: 고쳐져야 하는 값
        # e.g. {'2,8': '(數學)','34,37': ''}
        while brackets:
            index_key = str(brackets.start()) + "," + str(brackets.end())
            bracket = text[brackets.start() + 1 : brackets.end() - 1]
            infos = bracket.split(",")
            modi_infos = []
            for info in infos:
                info = info.strip()
                if len(info) > 0:
                    modi_infos.append(info)
            if len(modi_infos) > 0:
                replace_brackets[index_key] = "(" + ", ".join(modi_infos) + ")"
            else:
                replace_brackets[index_key] = ""
            brackets = bracket_pattern.search(text, brackets.start() + 1)
        end_index = 0
        for index_key in replace_brackets.keys():
            start_index = int(index_key.split(",")[0])
            modi_text += text[end_index:start_index]
            modi_text += replace_brackets[index_key]
            end_index = int(index_key.split(",")[1])
        modi_text += text[end_index:]
        modi_text = modi_text.strip()
        if modi_text:
            preprocessed_text.append(modi_text)
    return preprocessed_text

# %%
def clean_punc(texts):
    punct_mapping = {"‘": "'", "₹": "e", "´": "'", "°": "", "€": "e", "™": "tm", "√": " sqrt ", "×": "x", "²": "2", "—": "-", "–": "-", "’": "'", "_": "-", "`": "'", '“': '"', '”': '"', '“': '"', "£": "e", '∞': 'infinity', 'θ': 'theta', '÷': '/', 'α': 'alpha', '•': '.', 'à': 'a', '−': '-', 'β': 'beta', '∅': '', '³': '3', 'π': 'pi', }

    preprocessed_text = []
    for text in texts:
        for p in punct_mapping:
            text = text.replace(p, punct_mapping[p])
        text = text.strip()
        if text:
            preprocessed_text.append(text)
    return preprocessed_text

# %%
def remove_repeated_spacing(texts):
    """
    두 개 이상의 연속된 공백을 하나로 치환합니다.
    ``오늘은    날씨가   좋다.`` -> ``오늘은 날씨가 좋다.``
    """
    preprocessed_text = []
    for text in texts:
        text = re.sub(r"\s+", " ", text).strip()
        if text:
            preprocessed_text.append(text)
    return preprocessed_text

# %%
def spacing_sent(texts):
    spacing = Spacing()
    """
    띄어쓰기를 보정합니다.
    """
    preprocessed_text = []
    for text in texts:
        text = spacing(text)
        if text:
            preprocessed_text.append(text)
    return preprocessed_text

# %%
def spell_check_sent(texts):
    """
    맞춤법을 보정합니다.
    """
    preprocessed_text = []
    for text in texts:
        try:
            spelled_sent = spell_checker.check(text)
            checked_sent = spelled_sent.checked 
            if checked_sent:
                preprocessed_text.append(checked_sent)
        except:
            preprocessed_text.append(text)
    return preprocessed_text

# %%
def remove_stopwords(sents, stop_word_list):
    #  큰 의미가 없는 불용어 정의
    stopwords = stop_word_list
    preprocessed_text = []
    for sent in sents:
        sent = [w for w in sent.split(' ') if w not in stopwords]# 불용어 제거
        preprocessed_text.append(' '.join(sent))
    return preprocessed_text

# %%
def min_max_filter(texts,min_len = 2, max_len = 500):
    """
    문장을 최대, 최소 길이로 필터링합니다.
    """
    preprocessed_text = []
    for text in texts:
        preprocessed_text.append(re.sub(r'\(.*\)', '', text))
    return preprocessed_text

# %%
def remove_additional_brackets(texts):
    """
    sy; [ ], ( ) 사이값들 다 지워버리기
    """
    # text = '[역사 ]고려 시대에, 과거(科擧) 삼공(三貢)의 하나'
    # out = re.sub(r'\[.*\]', '', text)
    # print(out)
    
    preprocessed_text = []
    for text in texts:
        out = re.sub(r'\[.*\]', '', text)
        start_bracket = list(re.finditer('\(', out))
        end_bracket = list(re.finditer('\)', out))
        new_str = ''
        anchor = 0
        for _, (starts, ends) in enumerate(zip(start_bracket, end_bracket)):
            start_idx = starts.start()
            end_idx = ends.end()
            new_str += out[anchor:start_idx]
            anchor = end_idx
        new_str += out[anchor:]
        preprocessed_text.append(new_str)
    return preprocessed_text

# %%
def remove_hanja(texts):
    preprocessed_text = []
    pattern = re.compile(r'[,.^ ㄱ-ㅣ가-힣]+') #'[^ ㄱ-ㅣ가-힣]+' , '[ㄱ-ㅣ가-힣]'
    # result = hangul.sub('', s)
    # results = pattern.sub('', string)
    for text in texts:
        results = pattern.findall(text)
        if len(results) > 1:
            preprocessed_text.append('not hangeul only')
        else:
            preprocessed_text.append(text)
    return preprocessed_text

# %%
def run_preprocess(context):

    #불필요한 괄호제거
    context = remove_useless_breacket(context)
    #문장부호제거
    context = clean_punc(context)
    #연속공백제거
    context = remove_repeated_spacing(context)
    #연속 띄어쓰기 제거
    #context = spacing_sent(context)
    #불용어 제거
    stop_word_list = ['']
    context = remove_stopwords(context, stop_word_list)
    #최소최대길이 제한
    context = min_max_filter(context)

    # [] 제거, 여러개 ( * ) 제거
    context = remove_additional_brackets(context)
    
    # 위에 제거했는데도 한자 있는 애들은 제외 시키기
    context = remove_hanja(context)
    preprocessed_context = context
    return preprocessed_context

# %%
import re
string = "한자 부수의 하나. '鼾', '齈' 따위에 쓰인 '鼻'를 이른다."
pattern = re.compile(r'[^ ㄱ-ㅣ가-힣]+') #'[^ ㄱ-ㅣ가-힣]+' , '[ㄱ-ㅣ가-힣]'
# result = hangul.sub('', s)
# results = pattern.sub('', string)
results = pattern.findall(string)
# if len(results) > 1:

# %%
sample_context = list(train_df['v4'])
pro = run_preprocess(sample_context)
train_df.insert(column='v6', value=pro, loc=len(train_df.columns))

# %%
add_train_dir = '/content/WAI-VBZ-origin_synonyms.csv'
add_train_df = pd.read_csv(add_train_dir)
# VA_ant_df = add_train_df[add_train_df.is_replace==1].drop(columns='Unnamed: 0')

# %%
add_train_df.head()
# Out:
#    Unnamed: 0 original     synonyms
# 0           0  abandon  spontaneity
# 1           1  abandon    disregard
# 2           0    adays        A-day
# 3           1    adays        D-day
# 4           0    adieu     farewell

# %%
VBZ_syn_df = add_train_df.drop(columns='Unnamed: 0')

# %%
mapping = {VBZ_syn_df['original'].iloc[idx]: VBZ_syn_df['synonyms'].iloc[idx] for idx in range(len(VBZ_syn_df))}

# %%
syn = []
for _, (word, type_, _, _,_,_,_,_,_,_) in train_df.iterrows():
    if word in mapping:
        syn.append(mapping[word])
    else:
        syn.append('NaN')

# %%
train_df.insert(column='동의어', value=syn, loc=len(train_df.columns))
train_df.head(10)
# Out:
#          word type                         v1                       v2  \
# 0  afterhours  VBZ      영업시간후의, 폐점시간의(영업 등)      영업시간후의, 폐점시간의(영업 등)
# 1     amniote  VBZ                     양막류의                     양막류의
# 2    amoeboid  VBZ             아메바 모양의[비슷한]             아메바 모양의[비슷한]
# 3       anger  VBZ                   화나게 하다                   화나게 하다
# 4      apodal  VBZ    [동물] 발이 없는, 배지느러미가 없는    [동물] 발이 없는, 배지느러미가 없는
# 5        bats  VBZ       [영·속어]  정신 이상의, 미친               정신 이상의, 미친
# 6        caky  VBZ              케이크 같은, 뭉쳐진              케이크 같은, 뭉쳐진
# 7   catalyses  VBZ          [화학]  촉매 작용을 하다                촉매 작용을 하다
# 8   chemurgic  VBZ                  농예 화학의.                  농예 화학의.
# 9      chichi  VBZ     (장식이) 지나치게 복잡한[멋 부린]     (장식이) 지나치게 복잡한[멋 부린]
#
#                         v3  유의어                       v4                 v5  \
# 0    영업시간후의, 폐점시간의(영업 등)    NaN    영업시간후의, 폐점시간의(영업 등)        영업시간후의, 폐점시간의
# ...

# %%
train_df = train_df[train_df.v6!='Not verb']
train_df = train_df[train_df.v6!='not hangeul only']
train_df = train_df[train_df.v6!='Start with special character']

# %%
train_df
# Out:
#            word type                                v1  \
# 0    afterhours  VBZ             영업시간후의, 폐점시간의(영업 등)
# 1       amniote  VBZ                            양막류의
# 2      amoeboid  VBZ                    아메바 모양의[비슷한]
# 3         anger  VBZ                          화나게 하다
# 4        apodal  VBZ           [동물] 발이 없는, 배지느러미가 없는
# ..          ...  ...                               ...
# 61  sinistrorse  VBZ  [식물]  왼쪽으로 감기는(opp. dextrorse)
# 62         spry  VBZ                    (=sprightly)
# 63        tawie  VBZ             [스코]  (온)순한, 다루기 쉬운
# 64     topnotch  VBZ                  [구어]  일류의, 최고의
# 65       wanner  VBZ                   창백한, 파리한, 힘없는
#
#                          v2                       v3  유의어  \
# 0     영업시간후의, 폐점시간의(영업 등)      영업시간후의, 폐점시간의(영업 등)    NaN
# 1                    양막류의                     양막류의    NaN
# 2            아메바 모양의[비슷한]             아메바 모양의[비슷한]    NaN
# 3                  화나게 하다                   화나게 하다    NaN
# ...

# %%
train_df.to_csv('preprocessed_VBZ_v6.csv')
